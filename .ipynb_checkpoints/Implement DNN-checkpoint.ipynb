# %% [markdown]
# # Implement DNN on CIFAR10
# Ref: *https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#sphx-glr-beginner-blitz-cifar10-tutorial-py*

# %%
import torch
import torchvision
import torchvision.transforms as transforms

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
transform = transforms.Compose(
            [transforms.ToTensor(),
             transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=50,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=50,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np


# functions to show an image
def imshow(img):
    img = img / 2 + 0.5    # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
plt.show()
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#  deer  frog   dog  deer

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 12, 5)
        self.pool = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(12, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=800, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
def test():
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
    print('Accuracy of the network on the 10,000 test images: %d %%' %
          (100 * correct / total))

# %%
loss_hist = []
test_hist = []
for epoch in range(50):    # loop over the dataset multiple times
    
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward, backward, optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # print statistics
        running_loss += loss.item()
        if i % 240 == 239:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 240))
            loss_hist.append(running_loss / 240)
            running_loss = 0.0
    test()
            
print('Finished Training')
plt.plot(loss_hist)
plt.legend('Training Loss')
plt.title('Training Loss VS Time')
# Out:
# [1,   240] loss: 2.303
# [1,   480] loss: 2.302
# [1,   720] loss: 2.299
# [1,   960] loss: 2.285
# Accuracy of the network on the 10,000 test images: 18 %
# [2,   240] loss: 2.132
# [2,   480] loss: 1.995
# [2,   720] loss: 1.929
# [2,   960] loss: 1.850
# Accuracy of the network on the 10,000 test images: 35 %
# [3,   240] loss: 1.781
# [3,   480] loss: 1.731
# [3,   720] loss: 1.689
# [3,   960] loss: 1.670
# Accuracy of the network on the 10,000 test images: 39 %
# [4,   240] loss: 1.629
# [4,   480] loss: 1.618
# [4,   720] loss: 1.598
# [4,   960] loss: 1.571
# Accuracy of the network on the 10,000 test images: 42 %
# [5,   240] loss: 1.538
# [5,   480] loss: 1.526
# [5,   720] loss: 1.523
# [5,   960] loss: 1.499
# Accuracy of the network on the 10,000 test images: 45 %
# [6,   240] loss: 1.471
# [6,   480] loss: 1.462
# [6,   720] loss: 1.461
# [6,   960] loss: 1.448
# Accuracy of the network on the 10,000 test images: 48 %
# [7,   240] loss: 1.425
# [7,   480] loss: 1.403
# [7,   720] loss: 1.393
# [7,   960] loss: 1.397
# Accuracy of the network on the 10,000 test images: 48 %
# [8,   240] loss: 1.360
# [8,   480] loss: 1.361
# [8,   720] loss: 1.362
# [8,   960] loss: 1.332
# Accuracy of the network on the 10,000 test images: 51 %
# [9,   240] loss: 1.298
# [9,   480] loss: 1.321
# [9,   720] loss: 1.306
# [9,   960] loss: 1.309
# Accuracy of the network on the 10,000 test images: 51 %
# [10,   240] loss: 1.255
# [10,   480] loss: 1.278
# [10,   720] loss: 1.267
# [10,   960] loss: 1.274
# Accuracy of the network on the 10,000 test images: 54 %
# [11,   240] loss: 1.238
# [11,   480] loss: 1.224
# [11,   720] loss: 1.220
# [11,   960] loss: 1.230
# Accuracy of the network on the 10,000 test images: 55 %
# [12,   240] loss: 1.176
# [12,   480] loss: 1.191
# [12,   720] loss: 1.176
# [12,   960] loss: 1.200
# Accuracy of the network on the 10,000 test images: 57 %
# [13,   240] loss: 1.160
# [13,   480] loss: 1.128
# [13,   720] loss: 1.166
# [13,   960] loss: 1.148
# Accuracy of the network on the 10,000 test images: 57 %
# [14,   240] loss: 1.120
# [14,   480] loss: 1.125
# [14,   720] loss: 1.103
# [14,   960] loss: 1.108
# Accuracy of the network on the 10,000 test images: 58 %
# [15,   240] loss: 1.085
# [15,   480] loss: 1.064
# [15,   720] loss: 1.093
# [15,   960] loss: 1.104
# Accuracy of the network on the 10,000 test images: 59 %
# [16,   240] loss: 1.041
# [16,   480] loss: 1.064
# [16,   720] loss: 1.064
# [16,   960] loss: 1.062
# Accuracy of the network on the 10,000 test images: 60 %
# [17,   240] loss: 1.028
# [17,   480] loss: 1.041
# [17,   720] loss: 1.031
# [17,   960] loss: 1.017
# Accuracy of the network on the 10,000 test images: 60 %
# [18,   240] loss: 1.000
# [18,   480] loss: 0.997
# [18,   720] loss: 0.996
# [18,   960] loss: 1.005
# Accuracy of the network on the 10,000 test images: 60 %
# [19,   240] loss: 0.975
# [19,   480] loss: 0.969
# [19,   720] loss: 0.991
# [19,   960] loss: 0.976
# Accuracy of the network on the 10,000 test images: 60 %
# [20,   240] loss: 0.947
# [20,   480] loss: 0.952
# [20,   720] loss: 0.951
# [20,   960] loss: 0.955
# Accuracy of the network on the 10,000 test images: 62 %
# [21,   240] loss: 0.925
# [21,   480] loss: 0.928
# [21,   720] loss: 0.915
# [21,   960] loss: 0.939
# Accuracy of the network on the 10,000 test images: 62 %
# [22,   240] loss: 0.909
# [22,   480] loss: 0.907
# [22,   720] loss: 0.897
# [22,   960] loss: 0.920
# Accuracy of the network on the 10,000 test images: 63 %
# [23,   240] loss: 0.867
# [23,   480] loss: 0.875
# [23,   720] loss: 0.888
# [23,   960] loss: 0.893
# Accuracy of the network on the 10,000 test images: 61 %
# [24,   240] loss: 0.861
# [24,   480] loss: 0.839
# [24,   720] loss: 0.860
# [24,   960] loss: 0.884
# Accuracy of the network on the 10,000 test images: 64 %
# [25,   240] loss: 0.812
# [25,   480] loss: 0.854
# [25,   720] loss: 0.855
# [25,   960] loss: 0.847
# Accuracy of the network on the 10,000 test images: 62 %
# [26,   240] loss: 0.805
# [26,   480] loss: 0.805
# [26,   720] loss: 0.831
# [26,   960] loss: 0.823
# Accuracy of the network on the 10,000 test images: 63 %
# [27,   240] loss: 0.794
# [27,   480] loss: 0.791
# [27,   720] loss: 0.795
# [27,   960] loss: 0.820
# Accuracy of the network on the 10,000 test images: 63 %
# [28,   240] loss: 0.774
# [28,   480] loss: 0.775
# [28,   720] loss: 0.787
# [28,   960] loss: 0.807
# Accuracy of the network on the 10,000 test images: 64 %
# [29,   240] loss: 0.731
# [29,   480] loss: 0.768
# [29,   720] loss: 0.774
# [29,   960] loss: 0.786
# Accuracy of the network on the 10,000 test images: 63 %
# [30,   240] loss: 0.729
# [30,   480] loss: 0.760
# [30,   720] loss: 0.742
# [30,   960] loss: 0.762
# Accuracy of the network on the 10,000 test images: 64 %
# [31,   240] loss: 0.701
# [31,   480] loss: 0.727
# [31,   720] loss: 0.753
# [31,   960] loss: 0.739
# Accuracy of the network on the 10,000 test images: 65 %
# [32,   240] loss: 0.684
# [32,   480] loss: 0.727
# [32,   720] loss: 0.716
# [32,   960] loss: 0.723
# Accuracy of the network on the 10,000 test images: 64 %
# [33,   240] loss: 0.671
# [33,   480] loss: 0.697
# [33,   720] loss: 0.705
# [33,   960] loss: 0.720
# Accuracy of the network on the 10,000 test images: 64 %
# [34,   240] loss: 0.662
# [34,   480] loss: 0.688
# [34,   720] loss: 0.691
# [34,   960] loss: 0.686
# Accuracy of the network on the 10,000 test images: 65 %
# [35,   240] loss: 0.647
# [35,   480] loss: 0.672
# [35,   720] loss: 0.669
# [35,   960] loss: 0.688
# Accuracy of the network on the 10,000 test images: 64 %
# [36,   240] loss: 0.641
# [36,   480] loss: 0.652
# [36,   720] loss: 0.653
# [36,   960] loss: 0.658
# Accuracy of the network on the 10,000 test images: 64 %
# [37,   240] loss: 0.615
# [37,   480] loss: 0.628
# [37,   720] loss: 0.647
# [37,   960] loss: 0.655
# Accuracy of the network on the 10,000 test images: 65 %
# [38,   240] loss: 0.594
# [38,   480] loss: 0.615
# [38,   720] loss: 0.620
# [38,   960] loss: 0.642
# Accuracy of the network on the 10,000 test images: 64 %
# [39,   240] loss: 0.591
# [39,   480] loss: 0.599
# [39,   720] loss: 0.603
# [39,   960] loss: 0.630
# Accuracy of the network on the 10,000 test images: 64 %
# [40,   240] loss: 0.572
# [40,   480] loss: 0.592
# [40,   720] loss: 0.591
# [40,   960] loss: 0.620
# Accuracy of the network on the 10,000 test images: 64 %
# [41,   240] loss: 0.542
# [41,   480] loss: 0.573
# [41,   720] loss: 0.579
# [41,   960] loss: 0.597
# Accuracy of the network on the 10,000 test images: 65 %
# [42,   240] loss: 0.542
# [42,   480] loss: 0.556
# [42,   720] loss: 0.558
# [42,   960] loss: 0.586
# Accuracy of the network on the 10,000 test images: 65 %
# [43,   240] loss: 0.519
# [43,   480] loss: 0.540
# [43,   720] loss: 0.558
# [43,   960] loss: 0.579
# Accuracy of the network on the 10,000 test images: 64 %
# [44,   240] loss: 0.507
# [44,   480] loss: 0.531
# [44,   720] loss: 0.543
# [44,   960] loss: 0.550
# Accuracy of the network on the 10,000 test images: 64 %
# [45,   240] loss: 0.508
# [45,   480] loss: 0.516
# [45,   720] loss: 0.544
# [45,   960] loss: 0.535
# Accuracy of the network on the 10,000 test images: 64 %
# [46,   240] loss: 0.474
# [46,   480] loss: 0.516
# [46,   720] loss: 0.527
# [46,   960] loss: 0.522
# Accuracy of the network on the 10,000 test images: 65 %
# [47,   240] loss: 0.449
# [47,   480] loss: 0.497
# [47,   720] loss: 0.502
# [47,   960] loss: 0.519
# Accuracy of the network on the 10,000 test images: 64 %
# [48,   240] loss: 0.454
# [48,   480] loss: 0.468
# [48,   720] loss: 0.490
# [48,   960] loss: 0.509
# Accuracy of the network on the 10,000 test images: 64 %
# [49,   240] loss: 0.437
# [49,   480] loss: 0.449
# [49,   720] loss: 0.485
# [49,   960] loss: 0.497
# Accuracy of the network on the 10,000 test images: 63 %
# [50,   240] loss: 0.418
# [50,   480] loss: 0.459
# [50,   720] loss: 0.471
# [50,   960] loss: 0.457
# Accuracy of the network on the 10,000 test images: 63 %
# Finished Training
# Text(0.5, 1.0, 'Training Loss VS Time')

# %%
plt.plot(test_hist)
plt.legend('test_hist')
plt.title('test_hist VS Time')
# Out:
# Text(0.5, 1.0, 'test_hist VS Time')

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('Ground Truth ', ' '.join('%6s' % classes[labels[j]] for j in range(4)))
# Out:
# Ground Truth     cat   ship   ship  plane

# %%
outputs = net(images)

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-7c463b69189f> in <module>
# ----> 1 outputs = net(images)
#       2
#       3 _, predicted = torch.max(outputs, 1)
#       4
#       5 print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-4-6da8791da56c> in forward(self, x)
#      15
#      16     def forward(self, x):
# ---> 17         x = F.relu(self.conv1(x))
#      18         x = F.relu(self.conv2(x))
#      19         x = self.pool(F.relu(self.conv3(x)))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     336                             _pair(0), self.dilation, self.groups)
#     337         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 338                         self.padding, self.dilation, self.groups)
#     339
#     340
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1
            
        
for i in range(10):
    print('Accuracy of %5s : %2d %%' %
          (classes[i], 100 * class_correct[i] / class_total[i]))
